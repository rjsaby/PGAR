# %%
import arcpy
# ** Funciones
from PGAR_Diagnostico.PGAR_CamposVaciosDataset_V1 import identificar_campos_vacios
from PGAR_Diagnostico.PGAR_DiccionarioDatos import generacion_diccionario_datos
# ** Clases
from PGAR_Diagnostico.PGAR_NormalizacionCampos import normalizacion_campos
from PGAR_Diagnostico.PGAR_EstandarizacionRegistros import estandarizacion_campos

print(" ********************************** INICIO **********************************")

# # ** Variables Globales
# bd_trabajo = r"D:\PUBLIC\PGAR\Resultados\4.PRO\PGAR\_7_GDBs\PGAR_2023_2025.gdb"
# wilcard = '_*'

# # ** Asignación de espacio de trabajo
# arcpy.env.workspace = bd_trabajo
# # TODO: Ruta donde se almacenará el registro de campos vacíos por capa.
# ruta = r"D:\PUBLIC\PGAR\Resultados\4.PRO\PGAR\_10_Geoprocesos\Insumos_Diagnostico_Campos_Vacios"
# for dataset in arcpy.ListDatasets(wild_card=wilcard):
#         for feature_class in arcpy.ListFeatureClasses(feature_dataset = dataset):
#             # TODO: Los parámetros de la función -identificar_campos_vacios- son:
#             # TODO: feature_class: Capa a borrar los campos vacios
#             # TODO: Ruta donde quiere que se almacene los reportes de los campos que fueron eliminados
#             diccionario = identificar_campos_vacios(feature_class, ruta)
#             try:
#                 for llave, valor in diccionario.items():
#                     if len(valor) != 0:
#                         arcpy.management.DeleteField(feature_class, valor)
#                         print(f"Se eliminan campos vacios de la capa {feature_class}")
#                     else:
#                         print(f"La capa {feature_class} no requiere borrar campos")
#             except Exception as e:
#                 print(f"Se presenta una excepción en la capa {feature_class}, {e}")
                    
# print(" ********************************** ELIMINACIÓN DE CAMPOS VACIOS\BLANCO CONCLUIDO **********************************")
                    
# estandarizacion = normalizacion_campos(
#     bd_trabajo = r"D:\PUBLIC\PGAR\Resultados\4.PRO\PGAR\_7_GDBs\PGAR_2023_2025.gdb",
#     wilcard = '_*'
#     )

# print("Procedimiento: ", estandarizacion.proceso_normalizacion())

# print(" ********************************** NORMALIZACIÓN DE CAMPOS CONCLUIDO  **********************************")

# # ** Variables
# arcpy.env.workspace = r"D:\PUBLIC\PGAR\Resultados\4.PRO\PGAR\_7_GDBs\PGAR_2023_2025.gdb"
# wilcard = 'Insumos_Dia*'

# for dataset in arcpy.ListDatasets(wild_card=wilcard):
#         for feature_class in arcpy.ListFeatureClasses(feature_dataset = dataset):
#             estandarizacion = estandarizacion_campos(feature_class)
#             print(f"Se estandariza {feature_class}", estandarizacion.estandarizacionCampos())

# print(" ********************************** ESTANDARIZACIÓN DE REGISTROS CONCLUIDO  **********************************") 

"""La función cuenta con dos parámetros:
        rutaBaseDatos: Con la ruta de la base de datos sobre la que se quiere generar el diccionario de datos
        wilkcard = Si quiere tenerse encuenta algún dataset en particular
        rutaSalidaArchivos: La carpeta donde se quiere almacenar los XLSX resultantes con el diccionario de datos
"""
base_datos = r"D:\PUBLIC\PGAR\Resultados\4.PRO\PGAR\_7_GDBs\PGAR_2023_2025.gdb"
wildcard = '_*'
# ? Ruta donde se almacenará el diccionario de datos
ruta_archivos = r'D:\PUBLIC\PGAR\Resultados\4.PRO\Diccionario Datos'

ruta = generacion_diccionario_datos(base_datos,wildcard,ruta_archivos)

print(" ********************************** DEFINICIÓN DE DICCIONARIO CONCLUIDO  **********************************")
